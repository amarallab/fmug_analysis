# %%
import pandas as pd
import numpy as np

# %%
combo_df = pd.read_csv('../data/combined_hits.csv')
pmids_by_type = combo_df.groupby('type')['pubmed_id'].apply(set)

# %%
size = 10
np.random.seed(20)
a = np.random.choice(list(pmids_by_type['aff_ms']), size=10)
b = np.random.choice(list(pmids_by_type['transcriptomics']), size=10)
c = np.random.choice(list(pmids_by_type['gwas']), size=10)
d = np.random.choice(list(pmids_by_type['crispr']), size=10)

# %%
# APMS
a
# Out:
# array([29599191, 19295130, 26472337, 27307491, 30097533, 27503909,
#        24075985, 29045831, 28068325, 30209976])

# %% [markdown]
# https://pubmed.ncbi.nlm.nih.gov/?term=29599191%2C+19295130%2C+26472337%2C+27307491%2C+30097533%2C+27503909%2C+24075985%2C+29045831%2C+28068325%2C+30209976&sort=pubdate&format=abstract&size=200

# %%
# transcriptomics
b
# Out:
# array([24004674, 20818426, 20956553, 25267067, 25901080, 25464849,
#        23867476, 23576566, 22801492, 26313692])

# %% [markdown]
# https://pubmed.ncbi.nlm.nih.gov/?term=24004674%2C+20818426%2C+20956553%2C+25267067%2C+25901080%2C+25464849%2C++++++++23867476%2C+23576566%2C+22801492%2C+26313692&sort=pubdate&size=200

# %%
# gwas
c
# Out:
# array([20421499, 25772935, 29210060, 31600170, 20154341, 24014518,
#        21708048, 23571587, 25281659, 26822151])

# %% [markdown]
# https://pubmed.ncbi.nlm.nih.gov/?term=20421499%2C+25772935%2C+29210060%2C+31600170%2C+20154341%2C+24014518%2C++++++++21708048%2C+23571587%2C+25281659%2C+26822151&sort=pubdate&size=200

# %%
# crispr
d
# Out:
# array([31294695, 29526696, 28877469, 28877469, 30930145, 30194290,
#        30647128, 31353312, 31294695, 28894007])

# %% [markdown]
# https://pubmed.ncbi.nlm.nih.gov/?term=31294695%2C+29526696%2C+28877469%2C+28877469%2C+30930145%2C+30194290%2C++++++++30647128%2C+31353312%2C+31294695%2C+28894007&sort=pubdate&size=200

# %%
combo_df[(combo_df['pubmed_id'] == 19295130)].sort_values('mentioned')
# Out:
#       gene_ncbi  pubmed_id  mentioned  mentioned_citations   hit    type
# 1943     8065.0   19295130      False                False  True  aff_ms
# 1973    80067.0   19295130      False                False  True  aff_ms
# 1974    64708.0   19295130      False                False  True  aff_ms
# 1975    64326.0   19295130      False                False  True  aff_ms
# 1976    57542.0   19295130      False                False  True  aff_ms
# 1977    55626.0   19295130      False                False  True  aff_ms
# 1978    84861.0   19295130      False                False  True  aff_ms
# 1979     9684.0   19295130      False                False  True  aff_ms
# 1980    59349.0   19295130      False                False  True  aff_ms
# 1981     8533.0   19295130      False                False  True  aff_ms
# 1982    80344.0   19295130      False                False  True  aff_ms
# 1983   115290.0   19295130      False                False  True  aff_ms
# ...
